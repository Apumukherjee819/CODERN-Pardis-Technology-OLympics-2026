# %% [markdown]
# <h1 dir=ltr align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Absolute Cinema!
# </font>
# </h1>

# %% [markdown]
# <h2 dir="ltr" align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Introduction and Problem Statement
# </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
# In this question, you must define a function that, by receiving a user ID, suggests 10 movies that the user is likely to enjoy in the future.
# </font>
# </p>

# %% [markdown]
# <h2 dir="ltr" align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Dataset Introduction
# </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size="3">
# In the initial file of this question, there is a folder named <code>Data</code> which contains the dataset for the question.
# </font>
# </p>
#
# <p dir="ltr" style="direction: ltr; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size="3">
#
# </font>
# </p>

# %% [markdown]
# <h4 dir="ltr" align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Training Dataset Introduction
# </font>
# </h4>
#
# <div dir="ltr">
# <p dir="ltr" style="direction: ltr; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size="3">
#
# Our dataset includes columns with the following titles and descriptions, representing the nature and characteristics of user reviews.
#
# <center>
# <div dir="ltr" style="direction: ltr;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | **Column Name**    | **Description**                                                                   |
# | ------------------ | --------------------------------------------------------------------------------- |
# | `name_film`          | Movie name                                                                        |
# | `director`         | Movie director's name                                                             |
# | `imdb`             | Movie rating on IMDB                                                              |
# | `overal_rate`      | Average overall rating of Cinema-Plus platform users for this movie               |
# | `rates_count`      | Total number of users who rated this movie on the platform                        |
# | `user_id`          | Unique identifier of the user who submitted the review                            |
# | `comment_date`     | Date the review was submitted by the user                                         |
# | `comment_likes`    | Number of times this user's review was liked by others                            |
# | `comment_dislikes` | Number of times this user's review was disliked by others                         |
# | `comment_text`     | Review text and user's opinion about the movie                                    |
# | `movie_id`         | Unique identifier of the movie                                                    |
#
# </font>
# </div>
# </center>
#
# </font>
# </div>

# %%
# TODO:

# %% [markdown]
# <h2 dir="ltr" align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Suggester Function
# </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size="3">
# For this question, your goal is to write a suitable movie recommender function named <code>movie_suggestor</code>.
#     <br>
# This function must receive the ID of one of the users present in the dataset and output a list of ten movies that the user is likely to enjoy watching. The output of the function must be provided using the <code>return</code> statement (not printed). Additionally, the inference of the function must be as fast as possible. <b>Please note that the execution time for each test case must take less than 15 seconds. If it exceeds 15 seconds, you will receive a timeout error.</b>
# </font>
# </p>

# %%
# TODO:
def movie_suggestor(user_id):
    ...
    ...
    return...

# %%
# TODO:

# %% [markdown]
# <h2 dir="ltr" align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>Result Generator Cell</b>
# </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size="3">
#     Run the cell below to generate the <code>result.zip</code> file. Please note that you must save the changes made in the notebook (<code>ctrl+s</code>) before running the cell below; otherwise, your score will be changed to zero at the end of the competition.
#     <br>
#     Also, if you are using Colab to run this notebook file, download the latest version of your notebook and place it inside the submission file before submitting the <code>result.zip</code> file. Please ensure that the final zip file includes both <code>notebook.ipynb</code> and <code>movie_suggestor.py</code>.
# </font>
# </p>

# %%
import zipfile
import joblib
import os

if not os.path.exists(os.path.join(os.getcwd(), 'notebook.ipynb')):
    # %notebook -e notebook.ipynb

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

imp = """
import sklearn
import numpy as np
import pandas as pd
"""

# %save movie_suggestor imp + getsource(movie_suggestor)

file_names = ['notebook.ipynb', 'movie_suggestor.py']
compress(file_names)
