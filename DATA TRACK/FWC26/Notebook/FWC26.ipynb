# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Kylian the Dictator
# </font>
# </h1>

# %% [markdown]
# <p dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#         With the 2026 World Cup approaching, Kylian, deeply angered by the defeat in the previous round, has taken your family hostage and demanded you provide him with all available analytical information to understand his opponents and help him win the cup this time. To save your family, you must quickly fulfill Kylian's demands.
#         <br>
#         Your only tools are four raw datasets. From millions of records, you must extract <b>12 analytical reports</b>; from introducing the best penalty takers and young talents to analyzing winning streaks, giant killers, and the impact of decisive goals. If you complete the mission successfully, Kylian will release your family members.
#     </font>
# </p>
#
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Datasets
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#         The analysis team has provided you with the extracted information in the form of 4 separate files. The details of these datasets are as follows:
#     </font>
# </p>

# %% [markdown]
# <center>
# <div dir="ltr" style="direction: ltr;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | File Name | General Description |
# |:------:|:---:|
# |<code>results.csv</code>|Includes the history of all international football matches (date, tournament name, home/away team, goals, host city and country)|
# |<code>goalscorers.csv</code>|Includes details of goals scored in matches (scorer name, minute of goal, whether it was a penalty or not, scoring team)|
# |<code>elo_ratings_wc2026.csv</code>|Includes the history of national teams' Elo ratings, global Rank, and their point changes across various time snapshots|
# |<code>FC26.csv</code>|Includes comprehensive player information in the FC26 game (name, nationality, club, age, market value, wage, potential, and Overall rating)|
#
# </font>
# </div>
# </center>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

df_results = pd.read_csv('../Data/results.csv')
df_goalscorers = pd.read_csv('../Data/goalscorers.csv')
df_elo = pd.read_csv('../Data/elo_ratings_wc2026.csv')
df_fc26 = pd.read_csv('../Data/FC26.csv', low_memory=False)

df_results['date'] = pd.to_datetime(df_results['date'], format='mixed')
df_goalscorers['date'] = pd.to_datetime(df_goalscorers['date'], format='mixed')

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 1: Master Penalty Takers
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          List of 20 players who have scored the most international goals from the penalty spot. (Columns: <code>scorer_name</code>, <code>total_penalty_goals</code> | Sorting: Descending based on goals. In case of a tie, secondary ascending alphabetical sorting by player name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>penalty_specialists</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>scorer_name</code>|Scorer name|
# |<code>total_penalty_goals</code>|Total international goals from the penalty spot|
#
# </font>
# </div>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <b>Sorting:</b> Descending based on goals (in case of a tie, secondary ascending alphabetical sorting by player name).
# </p>

# %%
penalty_specialists = df_goalscorers[df_goalscorers['penalty'] == True]
penalty_specialists = penalty_specialists.groupby('scorer').size().reset_index(name='total_penalty_goals')
penalty_specialists = penalty_specialists.sort_values(
    by=['total_penalty_goals', 'scorer'], ascending=[False, True]
).head(20).reset_index(drop=True)
penalty_specialists.columns = ['scorer_name', 'total_penalty_goals']

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 2: Undervalued Wonderkids
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          Players aged 21 or younger in the FC26 file who have a value of more than 10 million euros and a wage of less than 20 thousand euros. (Columns: <code>short_name</code>, <code>age</code>, <code>value_eur</code>, <code>wage_eur</code>, <code>club_name</code> | Sorting: Ascending by wage, then descending by value. In case of a tie, secondary ascending alphabetical sorting by player name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>undervalued_wonderkids</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>short_name</code>|Player name|
# |<code>age</code>|Player age|
# |<code>value_eur</code>|Player value in euros|
# |<code>wage_eur</code>|Player wage in euros|
# |<code>club_name</code>|Current club name|
#
# </font>
# </div>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <b>Sorting:</b> Ascending by wage, then descending by value (in case of a tie, secondary ascending alphabetical sorting by player name).
# </p>

# %%
undervalued_wonderkids = df_fc26[
    (df_fc26['age'] <= 21) &
    (df_fc26['value_eur'] > 10_000_000) &
    (df_fc26['wage_eur'] < 20_000)
][['short_name', 'age', 'value_eur', 'wage_eur', 'club_name']].copy()
undervalued_wonderkids = undervalued_wonderkids.sort_values(
    by=['wage_eur', 'value_eur', 'short_name'], ascending=[True, False, True]
).reset_index(drop=True)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 3: Unconquerable Fortresses
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          Teams with the most home wins in tournament history. (Columns: <code>home_team</code>, <code>total_home_wins</code> | Sorting: Descending based on wins. In case of a tie, secondary ascending alphabetical sorting by team name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>home_fortresses</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>home_team</code>|Home team name|
# |<code>total_home_wins</code>|Total home wins|
#
# </font>
# </div>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <b>Sorting:</b> Descending based on wins (in case of a tie, secondary ascending alphabetical sorting by team name).
# </p>

# %%
home_wins = df_results[df_results['home_score'] > df_results['away_score']]
home_fortresses = home_wins.groupby('home_team').size().reset_index(name='total_home_wins')
home_fortresses = home_fortresses.sort_values(
    by=['total_home_wins', 'home_team'], ascending=[False, True]
).reset_index(drop=True)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 4: Continental Kings in 2025
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          The team that recorded the highest Elo rating in each confederation in the year 2025. (Columns: <code>confederation</code>, <code>country</code>, <code>max_rating_in_2025</code> | Sorting: Descending based on rating. In case of a tie, secondary ascending alphabetical sorting by country name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>confederation_kings</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>confederation</code>|Confederation or continent name|
# |<code>country</code>|Country name|
# |<code>max_rating_in_2025</code>|Highest Elo rating recorded in 2025|
#
# </font>
# </div>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <b>Sorting:</b> Descending based on rating (in case of a tie, secondary ascending alphabetical sorting by country name).
# </p>

# %%
elo_2025 = df_elo[df_elo['year'] == 2025]
idx = elo_2025.groupby('confederation')['rating'].idxmax()
confederation_kings = elo_2025.loc[idx, ['confederation', 'country', 'rating']].copy()
confederation_kings.columns = ['confederation', 'country', 'max_rating_in_2025']
confederation_kings = confederation_kings.sort_values(
    by=['max_rating_in_2025', 'country'], ascending=[False, True]
).reset_index(drop=True)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 5: Starting XI Strength
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          The average Overall rating for the top 11 players of the top 20 teams in the Elo rankings (teams with a rank less than or equal to 20). (Columns: <code>country_name</code>, <code>elo_rank_2026</code>, <code>avg_top11_overall</code> | Sorting: Descending based on average. In case of a tie, secondary ascending alphabetical sorting by country name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>starting_xi_strength</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>country_name</code>|Country name|
# |<code>elo_rank_2026</code>|Elo rank in 2026|
# |<code>avg_top11_overall</code>|Average Overall rating for the top 11 players|
#
# </font>
# </div>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <b>Sorting:</b> Descending based on average (in case of a tie, secondary ascending alphabetical sorting by country name).
# </p>

# %%
elo_2026 = df_elo[(df_elo['year'] == 2026) & (df_elo['snapshot_date'] == '12/31/2026')]
top20_elo = elo_2026[elo_2026['rank'] <= 20][['country', 'rank']].copy()
top20_elo.columns = ['country_name', 'elo_rank_2026']

results_xi = []
for _, row in top20_elo.iterrows():
    country = row['country_name']
    rank = row['elo_rank_2026']
    country_players = df_fc26[df_fc26['nationality_name'] == country]
    if len(country_players) >= 11:
        avg_overall = country_players.nlargest(11, 'overall')['overall'].mean()
    else:
        avg_overall = country_players['overall'].mean() if len(country_players) > 0 else 0
    results_xi.append({'country_name': country, 'elo_rank_2026': rank, 'avg_top11_overall': round(avg_overall, 2)})

starting_xi_strength = pd.DataFrame(results_xi).sort_values(
    by=['avg_top11_overall', 'country_name'], ascending=[False, True]
).reset_index(drop=True)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 6: Last-Minute Specialists
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          Players with the most goals scored from the 85th minute onwards, along with their physical stamina rating in FC26. (Columns: <code>scorer_name</code>, <code>late_goals_count</code>, <code>power_stamina</code>, <code>fc26_overall</code> | Sorting: Descending based on goals. In case of a tie, secondary ascending alphabetical sorting by player name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>late_goal_specialists</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>scorer_name</code>|Scorer name|
# |<code>late_goals_count</code>|Number of goals scored from the 85th minute onwards|
# |<code>power_stamina</code>|Physical stamina rating in FC26 game|
# |<code>fc26_overall</code>|Overall rating in FC26 game|
#
# </font>
# </div>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <b>Sorting:</b> Descending based on goals (in case of a tie, secondary ascending alphabetical sorting by player name).
# </p>

# %%
late_goals = df_goalscorers[df_goalscorers['minute'] >= 85]
late_count = late_goals.groupby('scorer').size().reset_index(name='late_goals_count')
late_count = late_count.sort_values(by=['late_goals_count', 'scorer'], ascending=[False, True]).head(20).reset_index(drop=True)

def make_fc26_key(name):
    parts = str(name).strip().split()
    if len(parts) >= 2:
        return parts[0][0] + '. ' + parts[-1]
    return name

fc26_long = {}
fc26_short = {}
for _, row in df_fc26.iterrows():
    ln, sn = row['long_name'], row['short_name']
    if pd.notna(ln) and ln not in fc26_long:
        fc26_long[ln] = (row['power_stamina'], row['overall'])
    if pd.notna(sn) and sn not in fc26_short:
        fc26_short[sn] = (row['power_stamina'], row['overall'])

def lookup_fc26(scorer):
    if scorer in fc26_long:
        return fc26_long[scorer]
    if scorer in fc26_short:
        return fc26_short[scorer]
    key = make_fc26_key(scorer)
    if key in fc26_short:
        return fc26_short[key]
    return (np.nan, np.nan)

late_count['power_stamina'] = late_count['scorer'].apply(lambda x: lookup_fc26(x)[0])
late_count['fc26_overall'] = late_count['scorer'].apply(lambda x: lookup_fc26(x)[1])
late_goal_specialists = late_count

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 7: High-Scoring Cities of the 2020s
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          Cities that have hosted at least 10 matches since 2020, along with the average goals per match. (Columns: <code>city</code>, <code>total_matches_hosted</code>, <code>total_goals_scored</code>, <code>avg_goals_per_match</code> | Sorting: Descending based on average goals. In case of a tie, secondary ascending alphabetical sorting by city name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>high_scoring_cities</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>city</code>|City name|
# |<code>total_matches_hosted</code>|Total number of matches hosted since 2020|
# |<code>total_goals_scored</code>|Total goals scored in this city|
# |<code>avg_goals_per_match</code>|Average goals per match|
#
# </font>
# </div>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <b>Sorting:</b> Descending based on average (in case of a tie, secondary ascending alphabetical sorting by city name).
# </p>

# %%
results_2020s = df_results[df_results['date'].dt.year >= 2020].copy()
results_2020s['total_goals'] = results_2020s['home_score'] + results_2020s['away_score']
city_stats = results_2020s.groupby('city').agg(
    total_matches_hosted=('total_goals', 'count'),
    total_goals_scored=('total_goals', 'sum')
).reset_index()
city_stats = city_stats[city_stats['total_matches_hosted'] >= 10]
city_stats['avg_goals_per_match'] = (city_stats['total_goals_scored'] / city_stats['total_matches_hosted']).round(2)
high_scoring_cities = city_stats.sort_values(
    by=['avg_goals_per_match', 'city'], ascending=[False, True]
).reset_index(drop=True)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 8: Club Footprints in International Matches
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          The number of international goalscorers and the total international goals of current players from each club. (Columns: <code>club_name</code>, <code>unique_international_scorers</code>, <code>total_international_goals_by_squad</code> | Sorting: Descending based on total goals. In case of a tie, secondary ascending alphabetical sorting by club name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>club_contributions</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>club_name</code>|Club name|
# |<code>unique_international_scorers</code>|Number of players from this club who have scored an international goal|
# |<code>total_international_goals_by_squad</code>|Total international goals of the club's current players|
#
# </font>
# </div>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <b>Sorting:</b> Descending based on total goals (in case of a tie, secondary ascending alphabetical sorting by club name).
# </p>

# %%
scorer_to_club = {}
for _, row in df_fc26.iterrows():
    ln, sn, club = row['long_name'], row['short_name'], row['club_name']
    if pd.notna(ln) and ln not in scorer_to_club:
        scorer_to_club[ln] = club
    if pd.notna(sn) and sn not in scorer_to_club:
        scorer_to_club[sn] = club

df_goals_valid = df_goalscorers[df_goalscorers['scorer'].notna()].copy()
df_goals_valid['club_name'] = df_goals_valid['scorer'].map(scorer_to_club)
goals_with_club = df_goals_valid[df_goals_valid['club_name'].notna()]

club_contributions = goals_with_club.groupby('club_name').agg(
    unique_international_scorers=('scorer', 'nunique'),
    total_international_goals_by_squad=('scorer', 'count')
).reset_index()
club_contributions = club_contributions.sort_values(
    by=['total_international_goals_by_squad', 'club_name'], ascending=[False, True]
).reset_index(drop=True)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 9: Game-Changing Goals
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          Players who have scored their team's equalizing or winning goal and an investigation of their national team's average Elo improvement during those same years (the difference between the Elo at the end of the year and the end of the previous year).<br><br><i>Columns:</i> <code>scorer_short_name</code>, <code>nationality_name</code>, <code>total_game_changing_goals</code>, <code>avg_elo_improvement</code>, <code>fc26_overall_rating</code><br><br><i>Sorting:</i> Ascending (alphabetical) based on <code>scorer_short_name</code>.
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>game_changing_goals</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>scorer_short_name</code>|Player name|
# |<code>nationality_name</code>|Player nationality|
# |<code>total_game_changing_goals</code>|Total number of equalizing or winning goals|
# |<code>avg_elo_improvement</code>|Average amount of the national team's Elo improvement (if there is no country data in the Elo dataset, use the phrase 'No Elo Data'. If multiple goals occur simultaneously, the default dataset order is the criterion) during those same years (difference between the end-of-year Elo and the end of the previous year)|
# |<code>fc26_overall_rating</code>|Player's Overall rating in the FC26 game|
#
# </font>
# </div>

# %%
# Build elo year-end lookup
elo_yearly = df_elo[df_elo['snapshot_date'].str.contains('12/31')].copy()
elo_yearly['year'] = elo_yearly['year'].astype(int)
elo_lookup = {}
for _, row in elo_yearly.iterrows():
    elo_lookup[(row['country'], row['year'])] = row['rating']

# Merge goals with results
goals_merged = df_goalscorers.merge(
    df_results[['date', 'home_team', 'away_team', 'home_score', 'away_score']],
    on=['date', 'home_team', 'away_team'], how='inner'
).sort_values(['date', 'home_team', 'away_team', 'minute'])

def process_match_group(grp):
    results = []
    home_team = grp['home_team'].iloc[0]
    away_team = grp['away_team'].iloc[0]
    final_hs = grp['home_score'].iloc[0]
    final_as = grp['away_score'].iloc[0]
    
    hg, ag = 0, 0
    goals_list = []
    for _, g in grp.iterrows():
        team = g['team']
        if team == home_team:
            hg += 1
        else:
            ag += 1
        goals_list.append((g['scorer'], team, hg, ag))
    
    hg, ag = 0, 0
    for scorer, team, h, a in goals_list:
        hg_before, ag_before = hg, ag
        if team == home_team:
            hg += 1
        else:
            ag += 1
        if team == home_team:
            my_before, their_before = hg_before, ag_before
            my_after, their_after = hg, ag
        else:
            my_before, their_before = ag_before, hg_before
            my_after, their_after = ag, hg
        if my_before < their_before and my_after == their_after:
            results.append({'scorer': scorer, 'type': 'equalizer'})
    
    # Determine winning goal
    if final_hs > final_as:
        winner = home_team
    elif final_as > final_hs:
        winner = away_team
    else:
        return results
    
    hg, ag = 0, 0
    for i, (scorer, team, h, a) in enumerate(goals_list):
        if team == home_team:
            hg += 1
        else:
            ag += 1
        if winner == home_team:
            ahead = hg > ag
        else:
            ahead = ag > hg
        if ahead:
            temp_hg, temp_ag = hg, ag
            stays = True
            for j in range(i+1, len(goals_list)):
                _, ft, _, _ = goals_list[j]
                if ft == home_team:
                    temp_hg += 1
                else:
                    temp_ag += 1
                if winner == home_team and temp_hg <= temp_ag:
                    stays = False
                    break
                elif winner == away_team and temp_ag <= temp_hg:
                    stays = False
                    break
            if stays:
                results.append({'scorer': scorer, 'type': 'winner'})
                break
    return results

match_groups = goals_merged.groupby(['date', 'home_team', 'away_team'])
all_gc = []
for keys, grp in match_groups:
    gcs = process_match_group(grp)
    for gc in gcs:
        all_gc.append({'scorer': gc['scorer'], 'type': gc['type'], 'date': keys[0]})

gc_df = pd.DataFrame(all_gc)

player_gc = gc_df.groupby('scorer').agg(
    total_game_changing_goals=('type', 'count')
).reset_index()

# Build FC26 lookup
fc26_nat = {}
fc26_ovr = {}
for _, row in df_fc26.iterrows():
    ln, sn = row['long_name'], row['short_name']
    if pd.notna(ln) and ln not in fc26_nat:
        fc26_nat[ln] = row['nationality_name']
        fc26_ovr[ln] = row['overall']
    if pd.notna(sn) and sn not in fc26_nat:
        fc26_nat[sn] = row['nationality_name']
        fc26_ovr[sn] = row['overall']

player_gc['nationality_name'] = player_gc['scorer'].map(fc26_nat)
player_gc['fc26_overall_rating'] = player_gc['scorer'].map(fc26_ovr)

# Get years of game-changing goals
player_years = gc_df.groupby('scorer')['date'].apply(
    lambda x: list(x.dt.year.unique())
).reset_index()
player_years.columns = ['scorer', 'years']
player_gc = player_gc.merge(player_years, on='scorer', how='left')

def get_elo_improvement(country, years):
    if pd.isna(country):
        return 'No Elo Data'
    improvements = []
    for year in sorted(years):
        cur = elo_lookup.get((country, year))
        prev = elo_lookup.get((country, year - 1))
        if cur is not None and prev is not None:
            improvements.append(cur - prev)
    if not improvements:
        return 'No Elo Data'
    return round(np.mean(improvements), 2)

player_gc['avg_elo_improvement'] = player_gc.apply(
    lambda r: get_elo_improvement(r['nationality_name'], r['years']) if isinstance(r['years'], list) else 'No Elo Data',
    axis=1
)

game_changing_goals = player_gc[['scorer', 'nationality_name', 'total_game_changing_goals', 'avg_elo_improvement', 'fc26_overall_rating']].copy()
game_changing_goals.columns = ['scorer_short_name', 'nationality_name', 'total_game_changing_goals', 'avg_elo_improvement', 'fc26_overall_rating']
game_changing_goals = game_changing_goals.sort_values(by='scorer_short_name', ascending=True).reset_index(drop=True)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 10: The Paradox of Potential and Team Decline
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          Countries that have dropped more than 50 Elo points in a single year but their players' average potential is among the top 10 percent globally, along with the number of losses in that year.<br><br><i>Columns:</i> <code>country_name</code>, <code>year_of_drop</code>, <code>elo_drop_amount</code>, <code>avg_fc26_potential</code>, <code>total_losses_in_year</code><br><br><i>Sorting:</i> Descending based on <code>elo_drop_amount</code> (in case of a tie, secondary ascending alphabetical sorting by country name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>underperforming_golden_generations</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>country_name</code>|Country name|
# |<code>year_of_drop</code>|The year the point drop occurred|
# |<code>elo_drop_amount</code>|Amount of Elo point drop|
# |<code>avg_fc26_potential</code>|Average potential of this country's players in FC26|
# |<code>total_losses_in_year</code>|Total number of losses in that year|
#
# </font>
# </div>

# %%
elo_yearly_sorted = elo_yearly.sort_values(['country', 'year'])
elo_yearly_sorted['elo_change'] = elo_yearly_sorted.groupby('country')['rating'].diff()
big_drops = elo_yearly_sorted[elo_yearly_sorted['elo_change'] < -50].copy()
big_drops['elo_drop_amount'] = big_drops['elo_change'].abs()

avg_potential = df_fc26.groupby('nationality_name')['potential'].mean().reset_index()
avg_potential.columns = ['country_name', 'avg_fc26_potential']
potential_threshold = avg_potential['avg_fc26_potential'].quantile(0.90)
top10_set = set(avg_potential[avg_potential['avg_fc26_potential'] >= potential_threshold]['country_name'])

df_results['year'] = df_results['date'].dt.year
losses_list = []
for _, row in df_results.iterrows():
    hs, as_ = row['home_score'], row['away_score']
    if hs > as_:
        losses_list.append({'year': row['year'], 'country': row['away_team']})
    elif as_ > hs:
        losses_list.append({'year': row['year'], 'country': row['home_team']})

losses_per_year = pd.DataFrame(losses_list).groupby(['year', 'country']).size().reset_index(name='total_losses_in_year')

big_drops_merged = big_drops.merge(avg_potential, left_on='country', right_on='country_name', how='left')
big_drops_merged = big_drops_merged[big_drops_merged['country'].isin(top10_set)]
big_drops_merged = big_drops_merged.merge(losses_per_year, on=['year', 'country'], how='left')

underperforming_golden_generations = big_drops_merged[['country', 'year', 'elo_drop_amount', 'avg_fc26_potential', 'total_losses_in_year']].copy()
underperforming_golden_generations.columns = ['country_name', 'year_of_drop', 'elo_drop_amount', 'avg_fc26_potential', 'total_losses_in_year']
underperforming_golden_generations = underperforming_golden_generations.sort_values(
    by=['elo_drop_amount', 'country_name'], ascending=[False, True]
).reset_index(drop=True)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 11: Giant Killers
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          Players who have scored a non-penalty goal in World Cup matches against a team with at least 300 Elo points higher than their own team.<br><br><i>Columns:</i> <code>giant_killer_name</code>, <code>player_team</code>, <code>opponent_team</code>, <code>elo_difference</code>, <code>goal_minute</code>, <code>player_value_eur</code><br><br><i>Sorting:</i> Ascending (alphabetical) based on <code>giant_killer_name</code>.
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>giant_killers</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>giant_killer_name</code>|Goalscorer name|
# |<code>player_team</code>|Player's national team|
# |<code>opponent_team</code>|Opponent team (Giant)|
# |<code>elo_difference</code>|Elo point difference between the two teams|
# |<code>goal_minute</code>|Minute the goal was scored|
# |<code>player_value_eur</code>|Player value in euros (for retired players not in the FC26 game, use the phrase 'Not in FC26')|
#
# </font>
# </div>

# %%
wc_results = df_results[df_results['tournament'] == 'FIFA World Cup'].copy()
wc_results['year'] = wc_results['date'].dt.year
wc_year_lookup = wc_results.set_index(['date', 'home_team', 'away_team'])['year'].to_dict()

wc_goals = df_goalscorers[
    df_goalscorers['penalty'] == False
].copy()
wc_goals['match_key'] = list(zip(wc_goals['date'], wc_goals['home_team'], wc_goals['away_team']))
wc_goals = wc_goals[wc_goals['match_key'].isin(wc_year_lookup.keys())].copy()

fc26_val = {}
for _, row in df_fc26.iterrows():
    ln, sn = row['long_name'], row['short_name']
    if pd.notna(ln) and ln not in fc26_val:
        fc26_val[ln] = row['value_eur']
    if pd.notna(sn) and sn not in fc26_val:
        fc26_val[sn] = row['value_eur']

giant_killer_rows = []
for _, goal in wc_goals.iterrows():
    match_key = (goal['date'], goal['home_team'], goal['away_team'])
    match_year = wc_year_lookup.get(match_key)
    if match_year is None:
        continue
    home_team, away_team = goal['home_team'], goal['away_team']
    scorer_team = goal['team']
    opponent_team = away_team if scorer_team == home_team else home_team
    elo_scorer = elo_lookup.get((scorer_team, match_year), elo_lookup.get((scorer_team, match_year - 1)))
    elo_opponent = elo_lookup.get((opponent_team, match_year), elo_lookup.get((opponent_team, match_year - 1)))
    if elo_scorer is not None and elo_opponent is not None:
        elo_diff = elo_opponent - elo_scorer
        if elo_diff >= 300:
            val = fc26_val.get(goal['scorer'], 'Not in FC26')
            giant_killer_rows.append({
                'giant_killer_name': goal['scorer'],
                'player_team': scorer_team,
                'opponent_team': opponent_team,
                'elo_difference': elo_diff,
                'goal_minute': goal['minute'],
                'player_value_eur': val
            })

giant_killers = pd.DataFrame(giant_killer_rows)
if len(giant_killers) > 0:
    giant_killers = giant_killers.sort_values(by='giant_killer_name', ascending=True).reset_index(drop=True)

# %% [markdown]
# <h2 align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
#     <font face="vazir" color="#0099cc">
#         Challenge 12: Elite Winning Streaks
#     </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <font face="vazir" size="3">
#          The longest consecutive winning streak for each team (excluding friendly matches) where all defeated opponents were among the top 10 in the rankings that year (Note: any draw, loss, or match against a team outside the top 10 breaks the streak).<br><br><i>Columns:</i> <code>team_name</code>, <code>max_win_streak_vs_top10</code>, <code>streak_start_date</code>, <code>streak_end_date</code>, <code>total_goals_scored_in_streak</code><br><br><i>Sorting:</i> Descending based on <code>max_win_streak_vs_top10</code> (in case of a tie, secondary ascending alphabetical sorting by team name).
#     </font>
#     <br>
#     <font face="vazir" color="red">
#         Output:
#     </font>
#     Store the result of the request in a dataframe named <code>elite_winning_streaks</code>.
#     This dataframe must include the following columns in this exact order:
# </p>
#
# <div dir="ltr" style="direction: ltr;text-align: left;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size="3">
#
# | Column | Description |
# |:------:|:---:|
# |<code>team_name</code>|Team name|
# |<code>max_win_streak_vs_top10</code>|Longest consecutive winning streak against top 10 teams|
# |<code>streak_start_date</code>|Streak start date|
# |<code>streak_end_date</code>|Streak end date|
# |<code>total_goals_scored_in_streak</code>|Total goals scored during this streak|
#
# </font>
# </div>

# %%
non_friendly = df_results[df_results['tournament'] != 'Friendly'].copy()
non_friendly['year'] = non_friendly['date'].dt.year

top10_per_year = {}
for year in elo_yearly['year'].unique():
    year_data = elo_yearly[elo_yearly['year'] == year].nsmallest(10, 'rank')
    top10_per_year[year] = set(year_data['country'].values)

all_streaks = []
all_teams = set(non_friendly['home_team'].unique()) | set(non_friendly['away_team'].unique())

for team in all_teams:
    home_m = non_friendly[non_friendly['home_team'] == team][['date', 'year', 'away_team', 'home_score', 'away_score']].copy()
    home_m['opponent'] = home_m['away_team']
    home_m['team_goals'] = home_m['home_score']
    home_m['opp_goals'] = home_m['away_score']
    
    away_m = non_friendly[non_friendly['away_team'] == team][['date', 'year', 'home_team', 'home_score', 'away_score']].copy()
    away_m['opponent'] = away_m['home_team']
    away_m['team_goals'] = away_m['away_score']
    away_m['opp_goals'] = away_m['home_score']
    
    team_matches = pd.concat([home_m, away_m]).sort_values('date').reset_index(drop=True)
    if len(team_matches) == 0:
        continue
    
    best_len = 0
    best_start = None
    best_end = None
    best_goals = 0
    cur_len = 0
    cur_start = None
    cur_end = None
    cur_goals = 0
    
    for _, m in team_matches.iterrows():
        is_win = m['team_goals'] > m['opp_goals']
        opp_in_top10 = m['opponent'] in top10_per_year.get(m['year'], set())
        
        if is_win and opp_in_top10:
            if cur_len == 0:
                cur_start = m['date']
            cur_len += 1
            cur_goals += m['team_goals']
            cur_end = m['date']
        else:
            if cur_len > best_len:
                best_len = cur_len
                best_start = cur_start
                best_end = cur_end
                best_goals = cur_goals
            cur_len = 0
            cur_start = None
            cur_end = None
            cur_goals = 0
    
    if cur_len > best_len:
        best_len = cur_len
        best_start = cur_start
        best_end = cur_end
        best_goals = cur_goals
    
    if best_len > 0:
        all_streaks.append({
            'team_name': team,
            'max_win_streak_vs_top10': best_len,
            'streak_start_date': best_start,
            'streak_end_date': best_end,
            'total_goals_scored_in_streak': best_goals
        })

elite_winning_streaks = pd.DataFrame(all_streaks)
if len(elite_winning_streaks) > 0:
    elite_winning_streaks = elite_winning_streaks.sort_values(
        by=['max_win_streak_vs_top10', 'team_name'], ascending=[False, True]
    ).reset_index(drop=True)

# %% [markdown]
# <h2 dir="ltr" align="left" style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>Result Generator Cell</b>
# </font>
# </h2>
#
# <p dir="ltr" style="direction: ltr; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size="3">
# &nbsp;&nbsp;&nbsp;&nbsp;Run the cell below to generate the <code>result.zip</code> file. Please note that you must save the changes made in the notebook (<code>ctrl+s</code>) before running the cell below; otherwise, your score will be changed to zero at the end of the competition.
# &nbsp;&nbsp;&nbsp;&nbsp;<br>
# &nbsp;&nbsp;&nbsp;&nbsp;Also, if you are using Colab to run this notebook file, download the latest version of your notebook and place it inside the submission file before submitting the <code>result.zip</code> file.
# </font>
# </p>

# %%
import zipfile
import os

if not os.path.exists(os.path.join(os.getcwd(), 'FWC26.ipynb')):
    # %notebook -e FWC26.ipynb

penalty_specialists.to_csv('penalty_specialists.csv', index=False)
undervalued_wonderkids.to_csv('undervalued_wonderkids.csv', index=False)
home_fortresses.to_csv('home_fortresses.csv', index=False)
confederation_kings.to_csv('confederation_kings.csv', index=False)
starting_xi_strength.to_csv('starting_xi_strength.csv', index=False)
late_goal_specialists.to_csv('late_goal_specialists.csv', index=False)
high_scoring_cities.to_csv('high_scoring_cities.csv', index=False)
club_contributions.to_csv('club_contributions.csv', index=False)
game_changing_goals.to_csv('game_changing_goals.csv', index=False)
underperforming_golden_generations.to_csv('underperforming_golden_generations.csv', index=False)
giant_killers.to_csv('giant_killers.csv', index=False)
elite_winning_streaks.to_csv('elite_winning_streaks.csv', index=False)

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

file_names = ['penalty_specialists.csv', 'undervalued_wonderkids.csv', 'home_fortresses.csv', 'confederation_kings.csv', 'starting_xi_strength.csv', 'late_goal_specialists.csv', 'high_scoring_cities.csv', 'club_contributions.csv', 'game_changing_goals.csv', 'underperforming_golden_generations.csv', 'giant_killers.csv', 'elite_winning_streaks.csv', 'FWC26.ipynb']
compress(file_names)
# Out:
# File Paths:
# ['penalty_specialists.csv', 'undervalued_wonderkids.csv', 'home_fortresses.csv', 'confederation_kings.csv', 'starting_xi_strength.csv', 'late_goal_specialists.csv', 'high_scoring_cities.csv', 'club_contributions.csv', 'game_changing_goals.csv', 'underperforming_golden_generations.csv', 'giant_killers.csv', 'elite_winning_streaks.csv', 'FWC26.ipynb']
